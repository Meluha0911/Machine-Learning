# %%
d = {'name':['sanket','shital','rohit'],
    'age':[24,29,32],
    'salary':[98000,75000,45000]}

# %%
import pandas as pd

# %%
data = pd.DataFrame(d,index=['a','b','c'])
data
# Out:
#      name  age  salary
# a  sanket   24   98000
# b  shital   29   75000
# c   rohit   32   45000

# %%
a = {'name':'sanket','age':24,'saalary':98000}
d = pd.Series(a)
d
# Out:
# name       sanket
# age            24
# saalary     98000
# dtype: object

# %%
d['name']
# Out:
# 'sanket'

# %%
data.loc[['a','b']]
# Out:
#      name  age  salary
# a  sanket   24   98000
# b  shital   29   75000

# %%
a = pd.read_csv(r'C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\data.csv')
a
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
a.loc[0]
# Out:
# Duration     60.0
# Pulse       110.0
# Maxpulse    130.0
# Calories    409.1
# Name: 0, dtype: float64

# %%
a.loc[[0,1,2,3,4,5]]
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0

# %%
s = pd.read_csv(r'C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\data.csv')
s.to_string()
# Out:
# '     Duration  Pulse  Maxpulse  Calories\n0          60    110       130     409.1\n1          60    117       145     479.0\n2          60    103       135     340.0\n3          45    109       175     282.4\n4          45    117       148     406.0\n5          60    102       127     300.0\n6          60    110       136     374.0\n7          45    104       134     253.3\n8          30    109       133     195.1\n9          60     98       124     269.0\n10         60    103       147     329.3\n11         60    100       120     250.7\n12         60    106       128     345.3\n13         60    104       132     379.3\n14         60     98       123     275.0\n15         60     98       120     215.2\n16         60    100       120     300.0\n17         45     90       112       NaN\n18         60    103       123     323.0\n19         45     97       125     243.0\n20         60    108       131     364.2\n21         45    100       119     282.0\n22         60    130       101 
# ...

# %%
data = pd.read_json(r'C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\data.js')
data.to_string()
# Out:
# '     Duration  Pulse  Maxpulse  Calories\n0          60    110       130     409.1\n1          60    117       145     479.0\n2          60    103       135     340.0\n3          45    109       175     282.4\n4          45    117       148     406.0\n5          60    102       127     300.5\n6          60    110       136     374.0\n7          45    104       134     253.3\n8          30    109       133     195.1\n9          60     98       124     269.0\n10         60    103       147     329.3\n11         60    100       120     250.7\n12         60    106       128     345.3\n13         60    104       132     379.3\n14         60     98       123     275.0\n15         60     98       120     215.2\n16         60    100       120     300.0\n17         45     90       112       NaN\n18         60    103       123     323.0\n19         45     97       125     243.0\n20         60    108       131     364.2\n21         45    100       119     282.0\n22         60    130       101 
# ...

# %%
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
data.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
data.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
data.tail(10)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB

# %%
data = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
newdata = data.dropna()
newdata
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 17      60.0  '2020/12/17'  100.0     120.0     300.0
# 19      60.0  '2020/12/19'  103.0     123.0     323.0
# 20      45.0  '2020/12/20'   97.0     125.0     243.0
# 21      60.0  '2020/12/21'  108.0     131.0     364.2
# 23      60.0  '2020/12/23'  130.0     101.0     300.0
# 29      60.0  '2020/12/29'  100.0     132.0     280.0
# 30      60.0  '2020/12/30'  102.0     129.0     380.3
# 31      60.0  '2020/12/31'   92.0     115.0     243.0

# %%
data = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
data.dropna(inplace=True)
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 17      60.0  '2020/12/17'  100.0     120.0     300.0
# 19      60.0  '2020/12/19'  103.0     123.0     323.0
# 20      45.0  '2020/12/20'   97.0     125.0     243.0
# 21      60.0  '2020/12/21'  108.0     131.0     364.2
# 23      60.0  '2020/12/23'  130.0     101.0     300.0
# 29      60.0  '2020/12/29'  100.0     132.0     280.0
# 30      60.0  '2020/12/30'  102.0     129.0     380.3
# 31      60.0  '2020/12/31'   92.0     115.0     243.0

# %%
data = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
data.fillna('sanket',inplace=True)
data
# Out:
#    Duration          Date   Pulse Maxpulse Calories
# 0      60.0  '2020/12/01'   110.0    130.0    409.1
# 1      60.0  '2020/12/02'   117.0    145.0    479.0
# 2      60.0  '2020/12/03'   103.0    135.0    340.0
# 3      45.0  '2020/12/04'   109.0    175.0    282.4
# 4      45.0  '2020/12/05'   117.0   sanket    406.0
# 5      60.0  '2020/12/06'   102.0   sanket    300.0
# 6      60.0  '2020/12/07'   110.0   sanket    374.0
# 7     450.0  '2020/12/08'  sanket   sanket    253.3
# 8      30.0  '2020/12/09'  sanket    133.0    195.1
# 9      60.0  '2020/12/10'  sanket    124.0    269.0
# 10     60.0  '2020/12/11'   103.0    147.0    329.3
# 11     60.0  '2020/12/12'   100.0    120.0    250.7
# 12     60.0  '2020/12/12'   100.0   sanket    250.7
# 13     60.0  '2020/12/13'   106.0   sanket    345.3
# 14     60.0  '2020/12/14'   104.0   sanket    379.3
# 15     60.0  '2020/12/15'    98.0   sanket    275.0
# 16     60.0  '2020/12/16'    98.0   sanket    215.2
# ...

# %%
data['Maxpulse'].fillna('sanket',inplace=True)
data
# Out:
#    Duration          Date   Pulse Maxpulse Calories
# 0      60.0  '2020/12/01'   110.0    130.0    409.1
# 1      60.0  '2020/12/02'   117.0    145.0    479.0
# 2      60.0  '2020/12/03'   103.0    135.0    340.0
# 3      45.0  '2020/12/04'   109.0    175.0    282.4
# 4      45.0  '2020/12/05'   117.0   sanket    406.0
# 5      60.0  '2020/12/06'   102.0   sanket    300.0
# 6      60.0  '2020/12/07'   110.0   sanket    374.0
# 7     450.0  '2020/12/08'  sanket   sanket    253.3
# 8      30.0  '2020/12/09'  sanket    133.0    195.1
# 9      60.0  '2020/12/10'  sanket    124.0    269.0
# 10     60.0  '2020/12/11'   103.0    147.0    329.3
# 11     60.0  '2020/12/12'   100.0    120.0    250.7
# 12     60.0  '2020/12/12'   100.0   sanket    250.7
# 13     60.0  '2020/12/13'   106.0   sanket    345.3
# 14     60.0  '2020/12/14'   104.0   sanket    379.3
# 15     60.0  '2020/12/15'    98.0   sanket    275.0
# 16     60.0  '2020/12/16'    98.0   sanket    215.2
# ...

# %%
data = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
a = data['Maxpulse'].mean()
data['Maxpulse'].fillna(a,inplace=True)
data
# Out:
#     Duration          Date  Pulse    Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0  130.000000     409.1
# 1       60.0  '2020/12/02'  117.0  145.000000     479.0
# 2       60.0  '2020/12/03'  103.0  135.000000     340.0
# 3       45.0  '2020/12/04'  109.0  175.000000     282.4
# 4       45.0  '2020/12/05'  117.0  128.727273     406.0
# 5       60.0  '2020/12/06'  102.0  128.727273     300.0
# 6       60.0  '2020/12/07'  110.0  128.727273     374.0
# 7      450.0  '2020/12/08'    NaN  128.727273     253.3
# 8       30.0  '2020/12/09'    NaN  133.000000     195.1
# 9       60.0  '2020/12/10'    NaN  124.000000     269.0
# 10      60.0  '2020/12/11'  103.0  147.000000     329.3
# 11      60.0  '2020/12/12'  100.0  120.000000     250.7
# 12      60.0  '2020/12/12'  100.0  128.727273     250.7
# 13      60.0  '2020/12/13'  106.0  128.727273     345.3
# 14      60.0  '2020/12/14'  104.0  128.727273     379.3
# 15      60.0  '2020/12/15'   98.0  128.727273     275.0
# ...

# %%
result = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
result['Date'] = pd.to_datetime(result['Date'])
result
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0       60.0 2020-12-01  110.0     130.0     409.1
# 1       60.0 2020-12-02  117.0     145.0     479.0
# 2       60.0 2020-12-03  103.0     135.0     340.0
# 3       45.0 2020-12-04  109.0     175.0     282.4
# 4       45.0 2020-12-05  117.0       NaN     406.0
# 5       60.0 2020-12-06  102.0       NaN     300.0
# 6       60.0 2020-12-07  110.0       NaN     374.0
# 7      450.0 2020-12-08    NaN       NaN     253.3
# 8       30.0 2020-12-09    NaN     133.0     195.1
# 9       60.0 2020-12-10    NaN     124.0     269.0
# 10      60.0 2020-12-11  103.0     147.0     329.3
# 11      60.0 2020-12-12  100.0     120.0     250.7
# 12      60.0 2020-12-12  100.0       NaN     250.7
# 13      60.0 2020-12-13  106.0       NaN     345.3
# 14      60.0 2020-12-14  104.0       NaN     379.3
# 15      60.0 2020-12-15   98.0       NaN     275.0
# 16      60.0 2020-12-16   98.0       NaN     215.2
# ...

# %%
result = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
result.dropna(subset = ['Date'],inplace=True)
result
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
data = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
data.loc[7,'Duration'] = 45.0
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7       45.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
for i in data.index:
    if data.loc[i,'Duration'] > 120:
        data.loc[i,'Duration'] = 120
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7       45.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
data.to_string()
# Out:
# "    Duration          Date  Pulse  Maxpulse  Calories\n0       60.0  '2020/12/01'  110.0     130.0     409.1\n1       60.0  '2020/12/02'  117.0     145.0     479.0\n2       60.0  '2020/12/03'  103.0     135.0     340.0\n3       45.0  '2020/12/04'  109.0     175.0     282.4\n4       45.0  '2020/12/05'  117.0       NaN     406.0\n5       60.0  '2020/12/06'  102.0       NaN     300.0\n6       60.0  '2020/12/07'  110.0       NaN     374.0\n7       45.0  '2020/12/08'    NaN       NaN     253.3\n8       30.0  '2020/12/09'    NaN     133.0     195.1\n9       60.0  '2020/12/10'    NaN     124.0     269.0\n10      60.0  '2020/12/11'  103.0     147.0     329.3\n11      60.0  '2020/12/12'  100.0     120.0     250.7\n12      60.0  '2020/12/12'  100.0       NaN     250.7\n13      60.0  '2020/12/13'  106.0       NaN     345.3\n14      60.0  '2020/12/14'  104.0       NaN     379.3\n15      60.0  '2020/12/15'   98.0       NaN     275.0\n16      60.0  '2020/12/16'   98.0       NaN     215.2\n17     
# ...

# %%
data = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
data.drop_duplicates(inplace=True)
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
data = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
data['new'] = 'sanket'
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories     new
# 0       60.0  '2020/12/01'  110.0     130.0     409.1  sanket
# 1       60.0  '2020/12/02'  117.0     145.0     479.0  sanket
# 2       60.0  '2020/12/03'  103.0     135.0     340.0  sanket
# 3       45.0  '2020/12/04'  109.0     175.0     282.4  sanket
# 4       45.0  '2020/12/05'  117.0       NaN     406.0  sanket
# 5       60.0  '2020/12/06'  102.0       NaN     300.0  sanket
# 6       60.0  '2020/12/07'  110.0       NaN     374.0  sanket
# 7      450.0  '2020/12/08'    NaN       NaN     253.3  sanket
# 8       30.0  '2020/12/09'    NaN     133.0     195.1  sanket
# 9       60.0  '2020/12/10'    NaN     124.0     269.0  sanket
# 10      60.0  '2020/12/11'  103.0     147.0     329.3  sanket
# 11      60.0  '2020/12/12'  100.0     120.0     250.7  sanket
# 12      60.0  '2020/12/12'  100.0       NaN     250.7  sanket
# 13      60.0  '2020/12/13'  106.0       NaN     345.3  sanket
# ...

# %%
data['new']
# Out:
# 0     sanket
# 1     sanket
# 2     sanket
# 3     sanket
# 4     sanket
# 5     sanket
# 6     sanket
# 7     sanket
# 8     sanket
# 9     sanket
# 10    sanket
# 11    sanket
# 12    sanket
# 13    sanket
# 14    sanket
# 15    sanket
# 16    sanket
# 17    sanket
# 18    sanket
# 19    sanket
# 20    sanket
# 21    sanket
# 22    sanket
# 23    sanket
# 24    sanket
# 25    sanket
# 26    sanket
# 27    sanket
# 28    sanket
# 29    sanket
# 30    sanket
# 31    sanket
# Name: new, dtype: object

# %%
data.loc[0]
# Out:
# Duration            60.0
# Date        '2020/12/01'
# Pulse              110.0
# Maxpulse           130.0
# Calories           409.1
# new               sanket
# Name: 0, dtype: object

# %%
data.loc[[0,1,2,3,4]]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories     new
# 0      60.0  '2020/12/01'  110.0     130.0     409.1  sanket
# 1      60.0  '2020/12/02'  117.0     145.0     479.0  sanket
# 2      60.0  '2020/12/03'  103.0     135.0     340.0  sanket
# 3      45.0  '2020/12/04'  109.0     175.0     282.4  sanket
# 4      45.0  '2020/12/05'  117.0       NaN     406.0  sanket

# %%
data.loc[0,'Duration']
# Out:
# 60.0

# %%
import pandas as pd

# %% [markdown]
# # DIFFERENT WAYS TO CREATE PANDAS DATAFRAME

# %%
df = pd.read_csv(r"C:\Users\sanke\Data Science\sample.csv")  #creating df using csv file
df
# Out:
#    Unnamed: 0  A   B
# 0           0  1   6
# 1           1  2   7
# 2           2  3   8
# 3           3  4   9
# 4           4  5  10

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#creating df using exel
df = pd.read_excel(r"C:\Users\sanke\Downloads\EmployeeSampleData\Employee Sample Data.xlsx")
df.to_string()
# Out:
# '       EEID             Full Name                       Job Title       Department           Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country            City  Exit Date\n0    E02387           Emily Davis                      Sr. Manger               IT  Research & Development  Female      Black   55 2016-04-08         141604     0.15  United States         Seattle 2021-10-16\n1    E04105         Theodore Dinh             Technical Architect               IT           Manufacturing    Male      Asian   59 1997-11-29          99975     0.00          China       Chongqing        NaT\n2    E02572          Luna Sanders                        Director          Finance     Speciality Products  Female  Caucasian   50 2006-10-26         163099     0.20  United States         Chicago        NaT\n3    E02832       Penelope Jordan        Computer Systems Manager               IT           Manufacturing  Female  Caucasian   26 2019-09-27          84913     
# ...

# %%
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
#create dataframe using dictionary
py_dict = {
    'name':['copper','silver','ironore','alumina'],
    'seg':['a','g','r','t'],
    'price':[234234,435,4335,453]
}

# %%
df = pd.DataFrame(py_dict)
df
# Out:
#       name seg   price
# 0   copper   a  234234
# 1   silver   g     435
# 2  ironore   r    4335
# 3  alumina   t     453

# %%
#creating dataframe from list of dictionary
py = [
    {'id':101,'sales':234234,'temp':32432},
    {'id':102,'sales':435456,'temp':23434},
    {'id':103,'sales':678585,'temp':87978},
]

# %%
df = pd.DataFrame(py,index=['a','b','c'])
df
# Out:
#     id   sales   temp
# a  101  234234  32432
# b  102  435456  23434
# c  103  678585  87978

# %%
# creating DF using API
df = pd.read_json(r"https://api.publicapis.org/entries")
df
# Out:
#       count                                            entries
# 0      1425  {'API': 'AdoptAPet', 'Description': 'Resource ...
# 1      1425  {'API': 'Axolotl', 'Description': 'Collection ...
# 2      1425  {'API': 'Cat Facts', 'Description': 'Daily cat...
# 3      1425  {'API': 'Cataas', 'Description': 'Cat as a ser...
# 4      1425  {'API': 'Cats', 'Description': 'Pictures of ca...
# ...     ...                                                ...
# 1420   1425  {'API': 'Visual Crossing', 'Description': 'Glo...
# 1421   1425  {'API': 'weather-api', 'Description': 'A RESTf...
# 1422   1425  {'API': 'WeatherAPI', 'Description': 'Weather ...
# 1423   1425  {'API': 'Weatherbit', 'Description': 'Weather'...
# 1424   1425  {'API': 'Yandex.Weather', 'Description': 'Asse...
#
# [1425 rows x 2 columns]

# %%
df = pd.read_html(r'https://en.wikipedia.org/wiki/Minnesota')
df
# Out:
# [                                            Minnesota  \
#  0                                               State
#  1   .mw-parser-output .ib-settlement-cols{text-ali...
#  2   Nickname(s): Land of 10,000 Lakes;North Star S...
#  3   Motto: L'Étoile du Nord (French: The Star of t...
#  4                           Anthem: "Hail! Minnesota"
#  5   Map of the United States with Minnesota highli...
#  6                                             Country
#  7                                    Before statehood
#  8                               Admitted to the Union
#  9                                             Capital
#  10                                       Largest city
#  11                       Largest county or equivalent
#  12                      Largest metro and urban areas
#  13                                         Government
#  14                                         • Governor
#  15                              • Lieutenant Governor
# ...

# %%
df = pd.DataFrame(py,index=['a','b','c'])
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['id', 'sales', 'temp'], dtype='object')

# %%
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
# fetch selected columns from the DF
df[['Duration','Date','Pulse']]
# Out:
#     Duration          Date  Pulse
# 0       60.0  '2020/12/01'  110.0
# 1       60.0  '2020/12/02'  117.0
# 2       60.0  '2020/12/03'  103.0
# 3       45.0  '2020/12/04'  109.0
# 4       45.0  '2020/12/05'  117.0
# 5       60.0  '2020/12/06'  102.0
# 6       60.0  '2020/12/07'  110.0
# 7      450.0  '2020/12/08'    NaN
# 8       30.0  '2020/12/09'    NaN
# 9       60.0  '2020/12/10'    NaN
# 10      60.0  '2020/12/11'  103.0
# 11      60.0  '2020/12/12'  100.0
# 12      60.0  '2020/12/12'  100.0
# 13      60.0  '2020/12/13'  106.0
# 14      60.0  '2020/12/14'  104.0
# 15      60.0  '2020/12/15'   98.0
# 16      60.0  '2020/12/16'   98.0
# 17      60.0  '2020/12/17'  100.0
# 18       NaN           NaN    NaN
# 19      60.0  '2020/12/19'  103.0
# 20      45.0  '2020/12/20'   97.0
# 21      60.0  '2020/12/21'  108.0
# 22      45.0           NaN  100.0
# 23      60.0  '2020/12/23'  130.0
# 24      45.0  '2020/12/24'    NaN
# 25      60.0  '2020/12/25'    NaN
# ...

# %%
# How to fetch those columns whose start with "D"
col_list = [col for col in df.columns if col.startswith('D')]
df[col_list]
# Out:
#     Duration          Date
# 0       60.0  '2020/12/01'
# 1       60.0  '2020/12/02'
# 2       60.0  '2020/12/03'
# 3       45.0  '2020/12/04'
# 4       45.0  '2020/12/05'
# 5       60.0  '2020/12/06'
# 6       60.0  '2020/12/07'
# 7      450.0  '2020/12/08'
# 8       30.0  '2020/12/09'
# 9       60.0  '2020/12/10'
# 10      60.0  '2020/12/11'
# 11      60.0  '2020/12/12'
# 12      60.0  '2020/12/12'
# 13      60.0  '2020/12/13'
# 14      60.0  '2020/12/14'
# 15      60.0  '2020/12/15'
# 16      60.0  '2020/12/16'
# 17      60.0  '2020/12/17'
# 18       NaN           NaN
# 19      60.0  '2020/12/19'
# 20      45.0  '2020/12/20'
# 21      60.0  '2020/12/21'
# 22      45.0           NaN
# 23      60.0  '2020/12/23'
# 24      45.0  '2020/12/24'
# 25      60.0  '2020/12/25'
# 26      60.0      20201226
# 27      60.0  '2020/12/27'
# 28      60.0  '2020/12/28'
# 29      60.0  '2020/12/29'
# 30      60.0  '2020/12/30'
# 31      60.0  '2020/12/31'

# %%
# To fetch single column you can use direct name
df['columnname']

# %%
# If want to fetch multiple column then we need to specify the list 
df[['columnname1','columnname2','columnname3','columnname4']]

# %%
# Single column can be fetch via two way's
1 -- df.columname
2 -- df['columnname']

# %%
df.Date
# Out:
# 0     '2020/12/01'
# 1     '2020/12/02'
# 2     '2020/12/03'
# 3     '2020/12/04'
# 4     '2020/12/05'
# 5     '2020/12/06'
# 6     '2020/12/07'
# 7     '2020/12/08'
# 8     '2020/12/09'
# 9     '2020/12/10'
# 10    '2020/12/11'
# 11    '2020/12/12'
# 12    '2020/12/12'
# 13    '2020/12/13'
# 14    '2020/12/14'
# 15    '2020/12/15'
# 16    '2020/12/16'
# 17    '2020/12/17'
# 18             NaN
# 19    '2020/12/19'
# 20    '2020/12/20'
# 21    '2020/12/21'
# 22             NaN
# 23    '2020/12/23'
# 24    '2020/12/24'
# 25    '2020/12/25'
# 26        20201226
# 27    '2020/12/27'
# 28    '2020/12/28'
# 29    '2020/12/29'
# 30    '2020/12/30'
# 31    '2020/12/31'
# Name: Date, dtype: object

# %%
df['Date']
# Out:
# 0     '2020/12/01'
# 1     '2020/12/02'
# 2     '2020/12/03'
# 3     '2020/12/04'
# 4     '2020/12/05'
# 5     '2020/12/06'
# 6     '2020/12/07'
# 7     '2020/12/08'
# 8     '2020/12/09'
# 9     '2020/12/10'
# 10    '2020/12/11'
# 11    '2020/12/12'
# 12    '2020/12/12'
# 13    '2020/12/13'
# 14    '2020/12/14'
# 15    '2020/12/15'
# 16    '2020/12/16'
# 17    '2020/12/17'
# 18             NaN
# 19    '2020/12/19'
# 20    '2020/12/20'
# 21    '2020/12/21'
# 22             NaN
# 23    '2020/12/23'
# 24    '2020/12/24'
# 25    '2020/12/25'
# 26        20201226
# 27    '2020/12/27'
# 28    '2020/12/28'
# 29    '2020/12/29'
# 30    '2020/12/30'
# 31    '2020/12/31'
# Name: Date, dtype: object

# %%
a = df.columns
df[a]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
# If I want df excluding some columns
exclude = [col for col in df.columns if 'Date' not in col]
df[exclude]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0       60.0  110.0     130.0     409.1
# 1       60.0  117.0     145.0     479.0
# 2       60.0  103.0     135.0     340.0
# 3       45.0  109.0     175.0     282.4
# 4       45.0  117.0       NaN     406.0
# 5       60.0  102.0       NaN     300.0
# 6       60.0  110.0       NaN     374.0
# 7      450.0    NaN       NaN     253.3
# 8       30.0    NaN     133.0     195.1
# 9       60.0    NaN     124.0     269.0
# 10      60.0  103.0     147.0     329.3
# 11      60.0  100.0     120.0     250.7
# 12      60.0  100.0       NaN     250.7
# 13      60.0  106.0       NaN     345.3
# 14      60.0  104.0       NaN     379.3
# 15      60.0   98.0       NaN     275.0
# 16      60.0   98.0       NaN     215.2
# 17      60.0  100.0     120.0     300.0
# 18       NaN    NaN       NaN       NaN
# 19      60.0  103.0     123.0     323.0
# 20      45.0   97.0     125.0     243.0
# 21      60.0  108.0     131.0     364.2
# ...

# %%
# how to get datatype of column
# for that we have two ways
# First
df.dtypes
# Out:
# Duration    float64
# Date         object
# Pulse       float64
# Maxpulse    float64
# Calories    float64
# dtype: object

# %%
df.info() # to get complete information about the DF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     float64
#  1   Date      30 non-null     object
#  2   Pulse     23 non-null     float64
#  3   Maxpulse  22 non-null     float64
#  4   Calories  30 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.4+ KB

# %%
df.describe() # Give short analysis of the DF
# Out:
#          Duration      Pulse    Maxpulse    Calories
# count   31.000000   23.00000   22.000000   30.000000
# mean    69.193548  104.73913  128.727273  304.680000
# std     71.064487    8.18656   14.323413   66.003779
# min     30.000000   92.00000  101.000000  195.100000
# 25%     60.000000  100.00000  120.000000  250.700000
# 50%     60.000000  103.00000  127.500000  291.200000
# 75%     60.000000  108.50000  132.000000  343.975000
# max    450.000000  130.00000  175.000000  479.000000

# %% [markdown]
# # Column Analysis

# %%
# How many values are there in the single column how to see that
df['Duration']
# Out:
# 0      60.0
# 1      60.0
# 2      60.0
# 3      45.0
# 4      45.0
# 5      60.0
# 6      60.0
# 7     450.0
# 8      30.0
# 9      60.0
# 10     60.0
# 11     60.0
# 12     60.0
# 13     60.0
# 14     60.0
# 15     60.0
# 16     60.0
# 17     60.0
# 18      NaN
# 19     60.0
# 20     45.0
# 21     60.0
# 22     45.0
# 23     60.0
# 24     45.0
# 25     60.0
# 26     60.0
# 27     60.0
# 28     60.0
# 29     60.0
# 30     60.0
# 31     60.0
# Name: Duration, dtype: float64

# %%
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
# To check unique values of the column 
df['Duration'].unique()
# Out:
# array([ 60.,  45., 450.,  30.,  nan])

# %%
df['Duration'].values # To get values from the DF
# Out:
# array([ 60.,  60.,  60.,  45.,  45.,  60.,  60., 450.,  30.,  60.,  60.,
#         60.,  60.,  60.,  60.,  60.,  60.,  60.,  nan,  60.,  45.,  60.,
#         45.,  60.,  45.,  60.,  60.,  60.,  60.,  60.,  60.,  60.])

# %%
df['Duration'].value_counts() # To get the count of the unique values from the DF
# Out:
# 60.0     24
# 45.0      5
# 450.0     1
# 30.0      1
# Name: Duration, dtype: int64

# %%
df['Date'].unique()
# Out:
# array(["'2020/12/01'", "'2020/12/02'", "'2020/12/03'", "'2020/12/04'",
#        "'2020/12/05'", "'2020/12/06'", "'2020/12/07'", "'2020/12/08'",
#        "'2020/12/09'", "'2020/12/10'", "'2020/12/11'", "'2020/12/12'",
#        "'2020/12/13'", "'2020/12/14'", "'2020/12/15'", "'2020/12/16'",
#        "'2020/12/17'", nan, "'2020/12/19'", "'2020/12/20'",
#        "'2020/12/21'", "'2020/12/23'", "'2020/12/24'", "'2020/12/25'",
#        '20201226', "'2020/12/27'", "'2020/12/28'", "'2020/12/29'",
#        "'2020/12/30'", "'2020/12/31'"], dtype=object)

# %%
len(df['Date'].unique()) # To get length of unique values from the DF
# Out:
# 30

# %%
# How to get count of each value in the DF
df['Duration'].value_counts()
# Out:
# 60.0     24
# 45.0      5
# 450.0     1
# 30.0      1
# Name: Duration, dtype: int64

# %%
df.shape # It gives the number of rows and columns in the DF
# Out:
# (32, 5)

# %%
# How to add new column in the DF bcz DF is the mutable
df = pd.DataFrame(py)
df
# Out:
#     id   sales   temp
# 0  101  234234  32432
# 1  102  435456  23434
# 2  103  678585  87978

# %%
df['new'] = 100
df
# Out:
#     id   sales   temp  new
# 0  101  234234  32432  100
# 1  102  435456  23434  100
# 2  103  678585  87978  100

# %%
df['idtemp'] = df['id'] + df['temp']
df
# Out:
#     id   sales   temp  new  idtemp
# 0  101  234234  32432  100   32533
# 1  102  435456  23434  100   23536
# 2  103  678585  87978  100   88081

# %%
df['mean'] = df['sales'].mean()
df # New column created along with the values added in it
# Out:
#     id   sales   temp  new  idtemp      mean
# 0  101  234234  32432  100   32533  449425.0
# 1  102  435456  23434  100   23536  449425.0
# 2  103  678585  87978  100   88081  449425.0

# %%
df['length'] = len(df['sales'])
df
# Out:
#     id   sales   temp  new  idtemp      mean  length
# 0  101  234234  32432  100   32533  449425.0       3
# 1  102  435456  23434  100   23536  449425.0       3
# 2  103  678585  87978  100   88081  449425.0       3

# %%
def l(n):
    return len(n)

# %%
df['sales'].value_counts()
# Out:
# 234234    1
# 435456    1
# 678585    1
# Name: sales, dtype: int64

# %%
len(df['sales'].values)
# Out:
# 3

# %%
df['lambda'] = df['id'].map(lambda x:x+2)
df # Using lambda Function in the DF
# Out:
#     id   sales   temp  new  idtemp      mean  length  lambda
# 0  101  234234  32432  100   32533  449425.0       3     103
# 1  102  435456  23434  100   23536  449425.0       3     104
# 2  103  678585  87978  100   88081  449425.0       3     105

# %%
# Get first and last rows of the DF
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0      60.0  '2020/12/01'  110.0     130.0     409.1
# 1      60.0  '2020/12/02'  117.0     145.0     479.0
# 2      60.0  '2020/12/03'  103.0     135.0     340.0
# 3      45.0  '2020/12/04'  109.0     175.0     282.4
# 4      45.0  '2020/12/05'  117.0       NaN     406.0

# %%
# How to get null values of the DF -- It will show True where there is Null value and Vice Versa.
df.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False      True     False
# 5      False  False  False      True     False
# 6      False  False  False      True     False
# 7      False  False   True      True     False
# 8      False  False   True     False     False
# 9      False  False   True     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False      True     False
# 13     False  False  False      True     False
# 14     False  False  False      True     False
# 15     False  False  False      True     False
# 16     False  False  False      True     False
# 17     False  False  False     False     False
# 18      True   True   True      True      True
# ...

# %%
# How to get count of the null values each column in the DF as True is 1 and False is 0.
df.isnull().sum()
# Out:
# Duration     1
# Date         2
# Pulse        9
# Maxpulse    10
# Calories     2
# dtype: int64

# %%
a = [1,2,3,34,54,6,6,8]
d = pd.Series(a)
d
# Out:
# 0     1
# 1     2
# 2     3
# 3    34
# 4    54
# 5     6
# 6     6
# 7     8
# dtype: int64

# %%
df['Duration'] = 60
df # Changing the existing column data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0     130.0     409.1
# 1         60  '2020/12/02'  117.0     145.0     479.0
# 2         60  '2020/12/03'  103.0     135.0     340.0
# 3         60  '2020/12/04'  109.0     175.0     282.4
# 4         60  '2020/12/05'  117.0       NaN     406.0
# 5         60  '2020/12/06'  102.0       NaN     300.0
# 6         60  '2020/12/07'  110.0       NaN     374.0
# 7         60  '2020/12/08'    NaN       NaN     253.3
# 8         60  '2020/12/09'    NaN     133.0     195.1
# 9         60  '2020/12/10'    NaN     124.0     269.0
# 10        60  '2020/12/11'  103.0     147.0     329.3
# 11        60  '2020/12/12'  100.0     120.0     250.7
# 12        60  '2020/12/12'  100.0       NaN     250.7
# 13        60  '2020/12/13'  106.0       NaN     345.3
# 14        60  '2020/12/14'  104.0       NaN     379.3
# 15        60  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
df['country'] = df['Country'].map(lambda x:str(x)[0:1])
# only fisrt letter of the column will be shown

# %%
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
# How to replace or fill null values in DF
df.fillna('empty_cell',inplace= True)
df
# Out:
#       Duration          Date       Pulse    Maxpulse    Calories
# 0         60.0  '2020/12/01'       110.0       130.0       409.1
# 1         60.0  '2020/12/02'       117.0       145.0       479.0
# 2         60.0  '2020/12/03'       103.0       135.0       340.0
# 3         45.0  '2020/12/04'       109.0       175.0       282.4
# 4         45.0  '2020/12/05'       117.0  empty_cell       406.0
# 5         60.0  '2020/12/06'       102.0  empty_cell       300.0
# 6         60.0  '2020/12/07'       110.0  empty_cell       374.0
# 7        450.0  '2020/12/08'  empty_cell  empty_cell       253.3
# 8         30.0  '2020/12/09'  empty_cell       133.0       195.1
# 9         60.0  '2020/12/10'  empty_cell       124.0       269.0
# 10        60.0  '2020/12/11'       103.0       147.0       329.3
# 11        60.0  '2020/12/12'       100.0       120.0       250.7
# 12        60.0  '2020/12/12'       100.0  empty_cell       250.7
# ...

# %%
new = df.to_csv()
new # DF to CSV conversion
# Out:
# ",Duration,Date,Pulse,Maxpulse,Calories\r\n0,60.0,'2020/12/01',110.0,130.0,409.1\r\n1,60.0,'2020/12/02',117.0,145.0,479.0\r\n2,60.0,'2020/12/03',103.0,135.0,340.0\r\n3,45.0,'2020/12/04',109.0,175.0,282.4\r\n4,45.0,'2020/12/05',117.0,empty_cell,406.0\r\n5,60.0,'2020/12/06',102.0,empty_cell,300.0\r\n6,60.0,'2020/12/07',110.0,empty_cell,374.0\r\n7,450.0,'2020/12/08',empty_cell,empty_cell,253.3\r\n8,30.0,'2020/12/09',empty_cell,133.0,195.1\r\n9,60.0,'2020/12/10',empty_cell,124.0,269.0\r\n10,60.0,'2020/12/11',103.0,147.0,329.3\r\n11,60.0,'2020/12/12',100.0,120.0,250.7\r\n12,60.0,'2020/12/12',100.0,empty_cell,250.7\r\n13,60.0,'2020/12/13',106.0,empty_cell,345.3\r\n14,60.0,'2020/12/14',104.0,empty_cell,379.3\r\n15,60.0,'2020/12/15',98.0,empty_cell,275.0\r\n16,60.0,'2020/12/16',98.0,empty_cell,215.2\r\n17,60.0,'2020/12/17',100.0,120.0,300.0\r\n18,empty_cell,empty_cell,empty_cell,empty_cell,empty_cell\r\n19,60.0,'2020/12/19',103.0,123.0,323.0\r\n20,45.0,'2020/12/20',97.0,125.0,243.0\r\n21,60.
# ...

# %%
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
df['Maxpulse'].fillna('maxpulse',inplace = True)
df # Fillna values in the specific column's
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0  maxpulse     406.0
# 5       60.0  '2020/12/06'  102.0  maxpulse     300.0
# 6       60.0  '2020/12/07'  110.0  maxpulse     374.0
# 7      450.0  '2020/12/08'    NaN  maxpulse     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0  maxpulse     250.7
# 13      60.0  '2020/12/13'  106.0  maxpulse     345.3
# 14      60.0  '2020/12/14'  104.0  maxpulse     379.3
# 15      60.0  '2020/12/15'   98.0  maxpulse     275.0
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandacsv.csv")
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# How to sort data of DF 
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# Sort on the basis -- if we use sort_insex then we had to mention on what basis you want to sort the data eg here wether 
# do sorting on the basis of column or wether to do on the basis of row's
# if I had to do sorting on the basis of column then I had to mention axis = 1
df.sort_index(axis=1) # here sorting will be done on the basis of column's alphabetically
# Out:
#                                            actors_list content_rating  \
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              R
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']              R
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              R
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...          PG-13
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....              R
# ..                                                 ...            ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...             PG
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...             PG
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...          PG-13
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...             PG
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...              R
#
#      duration      genre  star_rating  \
# 0         142      Crime          9.3
# 1         175      Crime          9.2
# ...

# %%
# How to sorting on the basis of row's -- this is not used
df.sort_index(axis = 0)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.sort_index(ascending=False) # row are arrange in the descending order -- by default it is True
# Out:
#      star_rating                                            title  \
# 978          7.4                                      Wall Street
# 977          7.4                                      Poltergeist
# 976          7.4  Master and Commander: The Far Side of the World
# 975          7.4                      Back to the Future Part III
# 974          7.4                                          Tootsie
# ..           ...                                              ...
# 4            8.9                                     Pulp Fiction
# 3            9.0                                  The Dark Knight
# 2            9.1                           The Godfather: Part II
# 1            9.2                                    The Godfather
# 0            9.3                         The Shawshank Redemption
#
#     content_rating      genre  duration  \
# 978              R      Crime       126
# 977             PG     Horror       114
# 976          PG-13     Action       138
# ...

# %%
# In sort_index we are just sorting index or column_name but not the actual values so to sort on the basis of values for eg.
# If we had to sort on the basis of values of column continent then use sort_values
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandacsv.csv")
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.sort_values(['continent'])
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 94866       ZWE    Africa  Zimbabwe  10/06/2021      39496.0       64.0
# 70909       RWA    Africa    Rwanda  30/03/2020         70.0        0.0
# 70910       RWA    Africa    Rwanda  31/03/2020         75.0        5.0
# 70911       RWA    Africa    Rwanda  01/04/2020         82.0        7.0
# 70912       RWA    Africa    Rwanda  02/04/2020         84.0        2.0
# ...         ...       ...       ...         ...          ...        ...
# 93537  OWID_WRL       NaN     World  06/06/2021  173310648.0   322641.0
# 93538  OWID_WRL       NaN     World  07/06/2021  173631266.0   320618.0
# 93539  OWID_WRL       NaN     World  08/06/2021  173999576.0   368310.0
# 93540  OWID_WRL       NaN     World  09/06/2021  174418411.0   418835.0
# 93541  OWID_WRL       NaN     World  10/06/2021  174867290.0   448879.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# How to arrange in descending
df.sort_values(['continent'],ascending=False)
# Out:
#        iso_code      continent  location        date  total_cases  new_cases  \
# 12307       BRA  South America    Brazil  14/10/2020    5140863.0    27235.0
# 67129       PRY  South America  Paraguay  06/06/2020       1090.0        3.0
# 67120       PRY  South America  Paraguay  28/05/2020        900.0       16.0
# 67121       PRY  South America  Paraguay  29/05/2020        917.0       17.0
# 67122       PRY  South America  Paraguay  30/05/2020        964.0       47.0
# ...         ...            ...       ...         ...          ...        ...
# 93537  OWID_WRL            NaN     World  06/06/2021  173310648.0   322641.0
# 93538  OWID_WRL            NaN     World  07/06/2021  173631266.0   320618.0
# 93539  OWID_WRL            NaN     World  08/06/2021  173999576.0   368310.0
# 93540  OWID_WRL            NaN     World  09/06/2021  174418411.0   418835.0
# 93541  OWID_WRL            NaN     World  10/06/2021  174867290.0   448879.0
#
# ...

# %%
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# sabse kam star rating wala record how to fetch that
df.sort_values(['star_rating'])
# Out:
#      star_rating                           title content_rating    genre  \
# 978          7.4                     Wall Street              R    Crime
# 950          7.4                           Bound              R    Crime
# 949          7.4                      Home Alone             PG   Comedy
# 948          7.4                      Frances Ha              R   Comedy
# 947          7.4                      Eraserhead        UNRATED    Drama
# ..           ...                             ...            ...      ...
# 6            8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 3            9.0                 The Dark Knight          PG-13   Action
# 2            9.1          The Godfather: Part II              R    Crime
# 1            9.2                   The Godfather              R    Crime
# 0            9.3        The Shawshank Redemption              R    Crime
#
#      duration                                        actors_list
# ...

# %%
# Sabse kum duration kiska tha how to get thatt
df.sort_values(['duration'])
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
# How to set any column as index in the DF
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv",index_col='genre')
df # so here rather than setting default index genre column will be taken as index
# Out:
#            star_rating                                            title  \
# genre
# Crime              9.3                         The Shawshank Redemption
# Crime              9.2                                    The Godfather
# Crime              9.1                           The Godfather: Part II
# Action             9.0                                  The Dark Knight
# Crime              8.9                                     Pulp Fiction
# ...                ...                                              ...
# Comedy             7.4                                          Tootsie
# Adventure          7.4                      Back to the Future Part III
# Action             7.4  Master and Commander: The Far Side of the World
# Horror             7.4                                      Poltergeist
# Crime              7.4                                      Wall Street
#
#           content_rating  duration  \
# genre
# Crime                  R       142
# ...

# %%
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
#how to set anyy column as index
df.set_index('duration',inplace=True)

# %%
df.sort_index() # now here sort on the basis of index which we had set
# Out:
#           star_rating                              title content_rating  \
# duration
# 64                8.0                             Freaks        UNRATED
# 66                8.0                Battleship Potemkin        UNRATED
# 67                8.1        The Cabinet of Dr. Caligari        UNRATED
# 68                8.1                          Duck Soup         PASSED
# 68                8.4                            The Kid      NOT RATED
# ...               ...                                ...            ...
# 220               7.9               The Ten Commandments       APPROVED
# 224               8.3  Lagaan: Once Upon a Time in India             PG
# 229               8.4        Once Upon a Time in America              R
# 238               8.2                 Gone with the Wind              G
# 242               7.8                             Hamlet          PG-13
#
#               genre                                        actors_list
# duration
# ...

# %%
# In short we can set any column as Index

# %%
# use of the iloc feature -- use to fetch rows
df.iloc[200]
# Out:
# star_rating                                                     8.1
# title                                                   Le Samourai
# content_rating                                                   PG
# genre                                                         Crime
# actors_list       [u'Alain Delon', u'Nathalie Delon', u'Fran\xe7...
# Name: 101, dtype: object

# %%
#How to reset index to the earlier one -- for that you can use rest_index
df.reset_index(inplace=True)
df
# Out:
#      duration  star_rating                                            title  \
# 0         142          9.3                         The Shawshank Redemption
# 1         175          9.2                                    The Godfather
# 2         200          9.1                           The Godfather: Part II
# 3         152          9.0                                  The Dark Knight
# 4         154          8.9                                     Pulp Fiction
# ..        ...          ...                                              ...
# 974       116          7.4                                          Tootsie
# 975       118          7.4                      Back to the Future Part III
# 976       138          7.4  Master and Commander: The Far Side of the World
# 977       114          7.4                                      Poltergeist
# 978       126          7.4                                      Wall Street
#
#     content_rating      genre  \
# ...

# %%
# How to remove column in the DF
df # here i want to drop start_rating column
# Out:
#      duration  star_rating                                            title  \
# 0         142          9.3                         The Shawshank Redemption
# 1         175          9.2                                    The Godfather
# 2         200          9.1                           The Godfather: Part II
# 3         152          9.0                                  The Dark Knight
# 4         154          8.9                                     Pulp Fiction
# ..        ...          ...                                              ...
# 974       116          7.4                                          Tootsie
# 975       118          7.4                      Back to the Future Part III
# 976       138          7.4  Master and Commander: The Far Side of the World
# 977       114          7.4                                      Poltergeist
# 978       126          7.4                                      Wall Street
#
#     content_rating      genre  \
# ...

# %%
#df.drop('star_rating') by default it will search in the row so it will not give result so what to do -- mentin here axis =1
df.drop('star_rating',axis = 1)
# Out:
#      duration                                            title content_rating  \
# 0         142                         The Shawshank Redemption              R
# 1         175                                    The Godfather              R
# 2         200                           The Godfather: Part II              R
# 3         152                                  The Dark Knight          PG-13
# 4         154                                     Pulp Fiction              R
# ..        ...                                              ...            ...
# 974       116                                          Tootsie             PG
# 975       118                      Back to the Future Part III             PG
# 976       138  Master and Commander: The Far Side of the World          PG-13
# 977       114                                      Poltergeist             PG
# 978       126                                      Wall Street              R
#
# ...

# %%
df.drop(1,inplace=True) # to remove rows -- by default axis = 0

# %%
df
# Out:
#      duration  star_rating                                            title  \
# 2         200          9.1                           The Godfather: Part II
# 3         152          9.0                                  The Dark Knight
# 4         154          8.9                                     Pulp Fiction
# 5          96          8.9                                     12 Angry Men
# 6         161          8.9                   The Good, the Bad and the Ugly
# ..        ...          ...                                              ...
# 974       116          7.4                                          Tootsie
# 975       118          7.4                      Back to the Future Part III
# 976       138          7.4  Master and Commander: The Far Side of the World
# 977       114          7.4                                      Poltergeist
# 978       126          7.4                                      Wall Street
#
#     content_rating      genre  \
# ...

# %%
# How to remove multiple columns at a single time
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.drop(columns=['star_rating','title','content_rating'])
# Out:
#          genre  duration                                        actors_list
# 0        Crime       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1        Crime       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2        Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       Action       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4        Crime       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..         ...       ...                                                ...
# 974     Comedy       116  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  Adventure       118  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976     Action       138  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977     Horror       114  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978      Crime       126  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 3 columns]

# %%
df.drop(['star_rating','content_rating'],axis=1)
# Out:
#                                                title      genre  duration  \
# 0                           The Shawshank Redemption      Crime       142
# 1                                      The Godfather      Crime       175
# 2                             The Godfather: Part II      Crime       200
# 3                                    The Dark Knight     Action       152
# 4                                       Pulp Fiction      Crime       154
# ..                                               ...        ...       ...
# 974                                          Tootsie     Comedy       116
# 975                      Back to the Future Part III  Adventure       118
# 976  Master and Commander: The Far Side of the World     Action       138
# 977                                      Poltergeist     Horror       114
# 978                                      Wall Street      Crime       126
#
#                                            actors_list
# ...

# %%
df.drop([0,1,2,3,4])
# Out:
#      star_rating                                            title  \
# 5            8.9                                     12 Angry Men
# 6            8.9                   The Good, the Bad and the Ugly
# 7            8.9    The Lord of the Rings: The Return of the King
# 8            8.9                                 Schindler's List
# 9            8.9                                       Fight Club
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 5        NOT RATED      Drama        96
# 6        NOT RATED    Western       161
# 7            PG-13  Adventure       201
# ...

# %%
df.set_index('genre')
# Out:
#            star_rating                                            title  \
# genre
# Crime              9.3                         The Shawshank Redemption
# Crime              9.2                                    The Godfather
# Crime              9.1                           The Godfather: Part II
# Action             9.0                                  The Dark Knight
# Crime              8.9                                     Pulp Fiction
# ...                ...                                              ...
# Comedy             7.4                                          Tootsie
# Adventure          7.4                      Back to the Future Part III
# Action             7.4  Master and Commander: The Far Side of the World
# Horror             7.4                                      Poltergeist
# Crime              7.4                                      Wall Street
#
#           content_rating  duration  \
# genre
# Crime                  R       142
# ...

# %%
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
df.dropna() #remove those row's which contain NaN
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 17      60.0  '2020/12/17'  100.0     120.0     300.0
# 19      60.0  '2020/12/19'  103.0     123.0     323.0
# 20      45.0  '2020/12/20'   97.0     125.0     243.0
# 21      60.0  '2020/12/21'  108.0     131.0     364.2
# 23      60.0  '2020/12/23'  130.0     101.0     300.0
# 29      60.0  '2020/12/29'  100.0     132.0     280.0
# 30      60.0  '2020/12/30'  102.0     129.0     380.3
# 31      60.0  '2020/12/31'   92.0     115.0     243.0

# %%
df['Maxpulse'].dropna() # Columnwise Drop NaN
# Out:
# 0     130.0
# 1     145.0
# 2     135.0
# 3     175.0
# 8     133.0
# 9     124.0
# 10    147.0
# 11    120.0
# 17    120.0
# 19    123.0
# 20    125.0
# 21    131.0
# 22    119.0
# 23    101.0
# 24    132.0
# 25    126.0
# 26    120.0
# 27    118.0
# 28    132.0
# 29    132.0
# 30    129.0
# 31    115.0
# Name: Maxpulse, dtype: float64

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
# By default how is any we can change how to any means agar pura row NaN hai tohi row delete karo otherwise don't 
df.dropna(how='all')
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
# thresh is use to specify NaN value means agar itna NaN hai tohi delete or drop karo column otherwise nahi
df = pd.read_csv(r"C:\Users\sanke\Downloads\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\Complete-Python-Pandas-Tutorial-in-Hindi-With-Notes--main\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 7      450.0  '2020/12/08'    NaN       NaN     253.3
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# ...

# %%
df.dropna(thresh =4) #means kamse kam row main atleast 2 non-null values honi chahiye otherwise wo row delete ho jayega
#agar row main 4 se kam non_null values hogi to wo row delete ho jayega
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0       60.0  '2020/12/01'  110.0     130.0     409.1
# 1       60.0  '2020/12/02'  117.0     145.0     479.0
# 2       60.0  '2020/12/03'  103.0     135.0     340.0
# 3       45.0  '2020/12/04'  109.0     175.0     282.4
# 4       45.0  '2020/12/05'  117.0       NaN     406.0
# 5       60.0  '2020/12/06'  102.0       NaN     300.0
# 6       60.0  '2020/12/07'  110.0       NaN     374.0
# 8       30.0  '2020/12/09'    NaN     133.0     195.1
# 9       60.0  '2020/12/10'    NaN     124.0     269.0
# 10      60.0  '2020/12/11'  103.0     147.0     329.3
# 11      60.0  '2020/12/12'  100.0     120.0     250.7
# 12      60.0  '2020/12/12'  100.0       NaN     250.7
# 13      60.0  '2020/12/13'  106.0       NaN     345.3
# 14      60.0  '2020/12/14'  104.0       NaN     379.3
# 15      60.0  '2020/12/15'   98.0       NaN     275.0
# 16      60.0  '2020/12/16'   98.0       NaN     215.2
# ...

# %%
# how main do parameters rehate hai -- any/all

# %%
# if I want to drop row which contain specific column for eg one row contain 'mumbai' as value in city column and I have to 
# drop that column then how to do it -- set column as index which contain that value and then use drop to delte that column
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# here I want to delete row which contain 'The Godfather' as a value or I want to delete "The Godfather"
df.set_index("title",inplace=True)

# %%
df.drop('The Godfather',inplace = True)

# %%
df #here I had successfully deleted row containing Godfather
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# 12 Angry Men                                             8.9      NOT RATED
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
# How to fetch subset of the dataset
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# How to fetch subset of the dataset
py_dict = {
    'name':['a','b','c','d','e'],
    'city':['pune','mumbai','pune','chennai','banglore'],
    'sal':[23213,124,3432,4324,3545],
    'id':[23432,234234,234,32534,454]
}

# %%
df = pd.DataFrame(py_dict)
df
#Suppose I just want particular record like I want only 'name' and 'id' or if I just want only 0 or 2 then we have
# loc and iloc
# in loc we use name -- syntax loc[row,column,step]
# in iloc we use integer location -- syntax loc[row,column,step]
# Out:
#   name      city    sal      id
# 0    a      pune  23213   23432
# 1    b    mumbai    124  234234
# 2    c      pune   3432     234
# 3    d   chennai   4324   32534
# 4    e  banglore   3545     454

# %%
df
# Out:
#   name      city    sal      id
# 0    a      pune  23213   23432
# 1    b    mumbai    124  234234
# 2    c      pune   3432     234
# 3    d   chennai   4324   32534
# 4    e  banglore   3545     454

# %%
# suppose I want column 'name' and 'id' with complete row's
df.loc[[0,1,2,3,4,5],['name','city']]
# Out:
#   name  city
# 0    a  pune

# %%
df.loc[[0,1,2,3,4]]
# Out:
#   name      city    sal      id
# 0    a      pune  23213   23432
# 1    b    mumbai    124  234234
# 2    c      pune   3432     234
# 3    d   chennai   4324   32534
# 4    e  banglore   3545     454

# %%
df[['name','id']] # like this we can directly access columns but to access index we need to use loc as shown below
# Out:
#   name      id
# 0    a   23432
# 1    b  234234
# 2    c     234
# 3    d   32534
# 4    e     454

# %%
df.loc[[0,1,2,3,4]] # This is how row's can br access you need to specify loc here
# Out:
#   name      city    sal      id
# 0    a      pune  23213   23432
# 1    b    mumbai    124  234234
# 2    c      pune   3432     234
# 3    d   chennai   4324   32534
# 4    e  banglore   3545     454

# %%
df.iloc[[0,1,2,3,4]]
# Out:
#   name      city    sal      id
# 0    a      pune  23213   23432
# 1    b    mumbai    124  234234
# 2    c      pune   3432     234
# 3    d   chennai   4324   32534
# 4    e  banglore   3545     454

# %%
df.loc[[1,2],['city','sal']]
# Out:
#      city   sal
# 1  mumbai   124
# 2    pune  3432

# %%
# what if I want all records of column 'name','city','sal'
df[['name','city','sal']]
# Out:
#   name      city    sal
# 0    a      pune  23213
# 1    b    mumbai    124
# 2    c      pune   3432
# 3    d   chennai   4324
# 4    e  banglore   3545

# %%
df.loc[:,'name':'sal'] #Another way to get record's
# Out:
#   name      city    sal
# 0    a      pune  23213
# 1    b    mumbai    124
# 2    c      pune   3432
# 3    d   chennai   4324
# 4    e  banglore   3545

# %%
df.loc[0:4,'name':'city']
# Out:
#   name      city
# 0    a      pune
# 1    b    mumbai
# 2    c      pune
# 3    d   chennai
# 4    e  banglore

# %%
# How to specify step here
df.loc[1::2]
# Out:
#   name     city   sal      id
# 1    b   mumbai   124  234234
# 3    d  chennai  4324   32534

# %%
df.loc[:,'name'::2]
# Out:
#   name    sal
# 0    a  23213
# 1    b    124
# 2    c   3432
# 3    d   4324
# 4    e   3545

# %%
# How to fetch data base on even index number
df.loc[[i for i in df.index if i%2==0]] # here we will get even index number record's
# Out:
#   name      city    sal     id
# 0    a      pune  23213  23432
# 2    c      pune   3432    234
# 4    e  banglore   3545    454

# %%
# How to fetch record where salary is greater than 4000
df[df['sal']>4000]
# Out:
#   name     city    sal     id
# 0    a     pune  23213  23432
# 3    d  chennai   4324  32534

# %%
# using iloc -- here we use integer index
df.iloc[:,1:3] #here we useinteger in place of name of the column in loc we use names of the column
# in iloc stop index is exclusive while in loc stop index is inclusive means it does not follow -1 rule
# in iloc we use integer here i means integer location
# Out:
#        city    sal
# 0      pune  23213
# 1    mumbai    124
# 2      pune   3432
# 3   chennai   4324
# 4  banglore   3545

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# How to use group by in the pandas
df1 = df.groupby('genre')  # It will give a object in the return

# %%
# We want particular group in the return then how to get that group
df1.get_group('Crime') # so here we will get data of crime
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
d = df1.get_group('Action')

# %%
d
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
d.value_counts()
# Out:
# star_rating  title                           content_rating  genre   duration  actors_list
# 7.4          La Femme Nikita                 R               Action  118       [u'Anne Parillaud', u'Marc Duret', u'Patrick Fontana']               1
# 7.9          The Man Who Would Be King       PG              Action  129       [u'Sean Connery', u'Michael Caine', u'Christopher Plummer']          1
# 8.1          Elite Squad                     R               Action  115       [u'Wagner Moura', u'Andr\xe9 Ramiro', u'Caio Junqueira']             1
#              A Fistful of Dollars            R               Action  99        [u'Clint Eastwood', u'Gian Maria Volont\xe9', u'Marianne Koch']      1
# 8.0          The Blues Brothers              R               Action  133       [u'John Belushi', u'Dan Aykroyd', u'Cab Calloway']                   1
# ...

# %%
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
len(df['genre'].unique())
# Out:
# 16

# %%
df.groupby('content_rating').get_group('PG')
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 30           8.6                                   Spirited Away
# 32           8.6                                      Casablanca
# 37           8.6                         Raiders of the Lost Ark
# ..           ...                                             ...
# 956          7.4                        Manhattan Murder Mystery
# 962          7.4                              Driving Miss Daisy
# 974          7.4                                         Tootsie
# 975          7.4                     Back to the Future Part III
# 977          7.4                                     Poltergeist
#
#     content_rating      genre  duration  \
# 12              PG     Action       124
# 19              PG     Action       121
# 30              PG  Animation       125
# ...

# %%
df.groupby('content_rating').get_group('R')
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 968          7.4       The English Patient              R      Drama
# 969          7.4       Law Abiding Citizen              R      Crime
# 970          7.4               Wonder Boys              R      Drama
# 971          7.4        Death at a Funeral              R     Comedy
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
# How to get multiple groups in the group by
df.groupby(['content_rating','genre']).get_group(('PG','Action'))
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 37           8.6                         Raiders of the Lost Ark
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 327          8.0                    The Adventures of Robin Hood
# 420          7.9                       The Man Who Would Be King
# 586          7.7                 Star Trek II: The Wrath of Khan
# 748          7.6                        The Hunt for Red October
# 753          7.6                            Escape from Alcatraz
# 764          7.6            Indiana Jones and the Temple of Doom
# 908          7.5                                         Bullitt
#
#     content_rating   genre  duration  \
# 12              PG  Action       124
# 19              PG  Action       121
# 37              PG  Action       115
# ...

# %%
# How to get 'PG' and 'R'
df[(df['content_rating'] == 'R')|(df['content_rating'] == 'PG')]
# Out:
#      star_rating                        title content_rating      genre  \
# 0            9.3     The Shawshank Redemption              R      Crime
# 1            9.2                The Godfather              R      Crime
# 2            9.1       The Godfather: Part II              R      Crime
# 4            8.9                 Pulp Fiction              R      Crime
# 8            8.9             Schindler's List              R  Biography
# ..           ...                          ...            ...        ...
# 971          7.4           Death at a Funeral              R     Comedy
# 974          7.4                      Tootsie             PG     Comedy
# 975          7.4  Back to the Future Part III             PG  Adventure
# 977          7.4                  Poltergeist             PG     Horror
# 978          7.4                  Wall Street              R      Crime
#
#      duration                                        actors_list
# ...

# %%
# How to use filter -- suppose I want PG 13 and genre action
df[(df['content_rating']=='PG13')|(df['genre']=='Action')]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df = pd.read_csv(r"C:\Users\sanke\Downloads\archive\city_temperature.csv")
df
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_14544\3543384498.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\sanke\Downloads\archive\city_temperature.csv")
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# ...

# %%
# I want country name whose temperature is max
df[df["AvgTemperature"]==df["AvgTemperature"].max()]['Country'] # df[] is use to construct DF from the result
# Out:
# 1034962    Kuwait
# Name: Country, dtype: object

# %%
# In the above first df[] is accessing df and ['Country'] is accessing the "Country" think here reverse then u can learn
# Pura record hume DF main chahiye isliye we have use df[]

# %%
# How to get both max and min temp in one query
df[(df["AvgTemperature"]==df["AvgTemperature"].max())|(df["AvgTemperature"]==df["AvgTemperature"].min())]
# Out:
#                 Region  Country                   State                  City  \
# 220             Africa  Algeria                     NaN               Algiers
# 221             Africa  Algeria                     NaN               Algiers
# 408             Africa  Algeria                     NaN               Algiers
# 409             Africa  Algeria                     NaN               Algiers
# 1453            Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2905471  North America       US  Additional Territories  San Juan Puerto Rico
# 2905534  North America       US  Additional Territories  San Juan Puerto Rico
# 2905689  North America       US  Additional Territories  San Juan Puerto Rico
# 2905726  North America       US  Additional Territories  San Juan Puerto Rico
# 2905749  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
# How to get count of min temperature
df[(df["AvgTemperature"]==df["AvgTemperature"].max())|(df["AvgTemperature"]==df["AvgTemperature"].min())]["AvgTemperature"].value_counts()
# Out:
# -99.0     79672
#  110.0        1
# Name: AvgTemperature, dtype: int64

# %%
# How to get min year temp
df[df['AvgTemperature'] == df['AvgTemperature'].min()]['Year']
# Out:
# 220        1995
# 221        1995
# 408        1996
# 409        1996
# 1453       1998
#            ...
# 2905471    2011
# 2905534    2011
# 2905689    2011
# 2905726    2011
# 2905749    2012
# Name: Year, Length: 79672, dtype: int64

# %%
# Year with maximum temperature
df[df['AvgTemperature']== df['AvgTemperature'].max()]['Year']
# Out:
# 1034962    2012
# Name: Year, dtype: int64

# %%
# city with maximun temperature
df[df['AvgTemperature']== df['AvgTemperature'].max()]['City']
# Out:
# 1034962    Kuwait
# Name: City, dtype: object

# %%
# Group_by on the year -- max temp of year 1995 by using group_by
df.groupby('Year').get_group(1995).max()
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_14544\4033602907.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.groupby('Year').get_group(1995).max()
# Region            South/Central America & Carribean
# Country                                      Zambia
# City                                         Zurich
# Month                                            12
# Day                                              31
# Year                                           1995
# AvgTemperature                                107.3
# dtype: object

# %%
# How to get country which has max temp in 2012
df.groupby('Year').get_group(2012).max()
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_14544\4150754123.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.groupby('Year').get_group(2012).max()
# Region            South/Central America & Carribean
# Country                                      Zambia
# City                                         Zurich
# Month                                            12
# Day                                              31
# Year                                           2012
# AvgTemperature                                110.0
# dtype: object

# %%
# select * from city_temp where Region == 'Africa'
df[df['Region'] == 'Africa']
# Out:
#         Region  Country State     City  Month  Day  Year  AvgTemperature
# 0       Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1       Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2       Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3       Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4       Africa  Algeria   NaN  Algiers      1    5  1995            47.9
# ...        ...      ...   ...      ...    ...  ...   ...             ...
# 251113  Africa   Zambia   NaN   Lusaka      1   18  2014            71.3
# 251114  Africa   Zambia   NaN   Lusaka      1   19  2014            77.5
# 251115  Africa   Zambia   NaN   Lusaka      1   20  2014            73.4
# 251116  Africa   Zambia   NaN   Lusaka      1   21  2014            73.1
# 251117  Africa   Zambia   NaN   Lusaka      1   22  2014            71.3
#
# [251118 rows x 8 columns]

# %%
# 19th day ko konse year me sabse jyda temp tha
df.groupby('Day').get_group(19).max()
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_14544\2802637979.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.groupby('Day').get_group(19).max()
# Region            South/Central America & Carribean
# Country                                      Zambia
# City                                         Zurich
# Month                                            12
# Day                                              19
# Year                                           2020
# AvgTemperature                                108.8
# dtype: object

# %%
# How to convert this data into Df -- df.groupby('Day').get_group(19).max()
df1 = pd.DataFrame(df.groupby('Day').get_group(19).max(),columns=['Data'])
df1
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_14544\1874328514.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1 = pd.DataFrame(df.groupby('Day').get_group(19).max(),columns=['Data'])
#                                              Data
# Region          South/Central America & Carribean
# Country                                    Zambia
# City                                       Zurich
# Month                                          12
# Day                                            19
# Year                                         2020
# AvgTemperature                              108.8

# %%
df = pd.read_csv(r"C:\Users\sanke\OneDrive\Documents\pandasmovies.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# I want that genre who has max rating
df[df['star_rating'] == df['star_rating'].max()]['genre']
# Out:
# 0    Crime
# Name: genre, dtype: object

# %%
df[df['star_rating'] == df['star_rating'].max()]['genre']
# Out:
# 0    Crime
# Name: genre, dtype: object

# %%
df[df['star_rating'] == df['star_rating'].min()]['genre'].value_counts()
# Out:
# Comedy       15
# Drama        12
# Adventure     7
# Crime         4
# Action        4
# Biography     3
# Animation     2
# Mystery       1
# Horror        1
# Name: genre, dtype: int64

# %%
# Movie which contain 'Godfather' name init

# %%
# using agg
df.groupby('star_rating').agg(['max','count'])
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_14544\4174579397.py:2: FutureWarning: ['content_rating'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('star_rating').agg(['max','count'])
#              title           genre       duration        \
#                max count       max count      max count
# star_rating
# 7.4          False    49   Mystery    49      175    49
# 7.5          False   108  Thriller   108      172   108
# 7.6          False   124   Western   124      205   124
# 7.7          False   113    Sci-Fi   113      202   113
# 7.8          False   116  Thriller   116      242   116
# 7.9          False    75   Western    75      220    75
# 8.0          False    97  Thriller    97      197    97
# 8.1          False   103   Western   103      212   103
# 8.2          False    51    Sci-Fi    51      238    51
# ...

# %%
# columns is use to get columns
df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
# Read API via pandas
df = pd.read_json(r'http://127.0.0.1:8000/api/details/')
df
# Out:
#    id   fname       fdate  ffare   ffrom     fto
# 0   1  Deccan  2023-07-08  10000  Mumbai  Satara
