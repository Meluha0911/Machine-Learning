# %% [markdown]
# # Difference Between AI vs ML vs DL vs DS

# %%
# ARTIFICIAL INTELLIGENCE
# Imagine entire universe as a AI. -- at the end of the day whatever role you are in -- you are working as a ML developer,
# AI developer, Vision developer, DS or an AI engineer at the end of the day you are creating an AI Applications.
# AI it is a process wherein we create some kind of applications in which it will be able to do it's task without any human
# interventiion's. So AI Application is able to do it's own task without any human intervention -- means a person need not 
# monitor this AI Application -- automatically it will be able to take decisions, it will be able to perform its task and 
# it will be able to do many things. 
# Eg. Netflix application -- it has AI module -- the work AI module do here is 
#   Recommendation -- if you watch kind of action movie for some time then AI module will give you recommendation on action 
#   movies. If I continously see comedy movie then it will give recommendation of comedy movie. -- So through this it is 
#   able to understand your behaviour and it is able to its task without asking you.
# Eg.Amazon also has AI module integrated init -- for example if you buy iphone then it will show you ipods, iwatch this
#    is because Amzon's AI module.
# Eg.Self Driving Cars -- Tesla -- Based on the road it is self driving
# So all this are examples of AI Application -- at the end of the day whatever role you are doing, you are creating an AI
# Applications.

# %%
# MACHINE LEARNING
# It is a subset of AI.
# It provides stat tools to analyse the data, visualise the data and apart from that to do predictions and forecasting so 
# whatever ML algorithms we are using all those will have some stat tools in it.

# %%
# DEEP LEARNING 
# It is a subset of ML.
# It comes into existence bcz in 1950-60 scientist thought that can Machine learn like we as a human learn so for this prpse
# DL come into existence -- so plan is to mimic human brain -- means we are trying to mimic human brain to mimic something,
# to learn something -- so for this we use multilayered neural networks.
# This MultiLayered Neural Networks will help us to train the Machines or Applications we create.
# With help of DL we able to solve complex problems, business usecase.

# %%
# As a data scientist is part of everything i.e AI,ML,DL

# %%
# wrt any kind of problem statement that we solve the majority of business usecases will fall into 2 sections
# one is supervised ML and other is Unsupervised ML -- So most of the problem basically you are solving -- this are two 
# types of ML algorithms.

# Supervised ML
# -- Two major ML problems you are solving in Supervised ML -- one is Regression Problem and other is called Classification
#    problem.

# Unsupervised ML
# -- In UML you are solving two different types of problems one is clustering and other is dimnesionality reduction
#    Other ML type is called -- Reinforecement ML -- it has different techniques.

# %%
# SUPERVISED ML
# -- Suppose I have a dataset in which there are two features(column's) age and weight with values like age[24,25,21,27]
#    weight[62,63,62,72] over here my task is to take this particular data and create a model -- wherein when I give a age 
#    to a trained model as a input it should be able to predict the weight. -- This particular model is called hypothesis.
# -- what are the imporatant components when we have this kind of problem statement -- there are two important features 
#    one is INDEPENDENT Featrues and other is DEPENDENT Features.
# -- Independent feature in this case means -- since the input that I am training in that all becomes Independent features.
#    here age is a Independent feature. Whatever I am predicting that is my output so this is Dependent Feature. We are 
#    calling it dependent feature bcz it is completely dependening on Independen Features. Whenever Indepdent Features are
#    increasing or decreasing this dependent features are getting changed. Whenever we are solving the problem in the case 
#    of SML there will be One dependent Feature and there can be multiple Independent Features.
# -- Difference between Regression and Classification
# -- REGRESSION 
#    -- Suppose I have a dataset in which there are two features(column's) age and weight with values like age[24,25,21,27]
#       weight[62,63,62,72] -- weight is my dependent feature -- in this particular dependent feature -- I have a continous 
#       variable -- when you have a continous variable then it becomes the regression problem statement. Whenever your outpt
#       is continous then it becomes Regression Problem Statement. In Regression Problem Statement our output will be in a 
#       continous variable.
# -- CLASSIFICATION
#    -- Suppose I have a dataset with Independent Features like No of Study Hrs, No of Playing Hrs, No of Sleeping HRs and 
#       dependent feature is output which will be pass or fail -- in output[p,f,p,f,f,p,f] like this -- so whenever in 
#       output you have fix number of categories then that becomes a classification problem -- suppose it just has two 
#       outputs then it becomes the Binary Classification -- If you have more than two categories then it becomes Multi-
#       class classification.

# %%
# UNSUPERVISED ML
# -- there are two problem statements we are going to solve -- one is clustering and other is dimensionality reduction
# -- CLUSTERING
# -- Suppose I have dataset with salary and age as Independent Feature -- in this scenario we dont have output varialbe i.e
#    we dont have Dependent Variable -- so in this case what kind of assumption we can have from this particular dataset --
#    so in this particular case I would like to do something called as Clustering -- why clustering is used -- I ma going 
#    to do something known as Customer Segmentation -- What does this Customer Segmentation will do -- Clustering means base
#    on this data [age,salary] I will try to find out similar groups -- groups of people -- for eg 1st group, 2nd group,
#    3rd group so base on this I will able to create this many gropus -- i.e clusters i.e cluster 1, 2 and 3 -- each and 
#    every cluster will be specifying some information -- cluster 1 will specify that this person was very young and he was 
#    getting this amazing salary, cluster 2 specify may specify that this people have more age and they are getting good
#    salary, cluster 3 may specify that this people are from middleclass background but salary is not that much increasing.
#    so here we are doing clustering we are doing grouping -- word grouping is imp.
#    Suppose my company launches a product and I want to target this particular product to just rich people lets say product
#    1 is for rich people, product 2 is for middleclass people -- so if I make this kind of clusters so I willbe able to 
#    target my adds only to this kind of people say rich people or mc people -- so if I do grouping I can send ads to those
#    particular group of people -- this is admarketing -- this uses something called as Customer Segmentation -- and based
#    on this CS we can later apply any Regression or Classification kind of problem statement.
# -- DIMENSIONALITY REDUCTION
#    -- Suppose if we have 1000 features can we reduce this features to lower dimensions -- lets say I want to convert this
#       1000 features to 100 features to lower dimesion -- can we do that -- yes it is possible -- with the help of 
#       dimensionality reduction algorithm like PCA, etc.
# -- clustering is not a classification problem clustering is a grouping algorithm, there is no output (dependent feature)
#    algorithm in the USML.

# %%
# Algorithms will be covered 
# SUPERVISED ML
# 1. Linear Regression
# 2. Ridge and Lasso
# 3. Logistic Regression
# 4. Decision Tree -- It includes both classification and regression
# 5. Adaboost
# 6. Random Forest
# 7. Gradient Boosting
# 8. Xgboost
# 9. Naive Bayies
# 10. SVM
# 11. KNN

# UNSUPERVISED ML
# 1. K means
# 2. DB scan
# 3. Hiearchical Clustering
# 4. K nearest Neighbour Clustering
# 5. PCA
# 6. LDA

# %% [markdown]
# # LINEAR REGRESSION

# %%
# suppose I have two features x[age] and y[weight] -- so base on this features I have some datapoints that is been present
# in the graph -- see SS(34.24 Live Session 1) -- so in LR what we try to do is that -- in linear regression we try to 
# create a model -- with the help of this training dataset I am going to basically train a model -- and this model is noting
# but a kind of a hypothesis testing or it is just kind of hypothesis which takes later on training the model the new_age
# and gives the output of the weight and with the help of performance matrixs we are trying to verify wether this model is 
# performing well or not -- now inshort what we are going to do in linear regression is that we are going to find out the
# best-fit line which will actually help us to get the prediction -- that means if I get my new_age here than what wiil be
# my output wrt y. (see ss 35.34 live1) i.e what we need to predict. -- In this case when we draw a diagram like this (ss)
# we can say that y is a linear function of x -- So this is what we are going to do -- How we are going to create this
# best-fit line this is very much important -- whenever we say LR it basically means that we are going to create a linear 
# line over there.
# Equation of best-fitline is [y = mx+c]
# Equation of straightline (see SS 38.17 live 1)
# h thita 0 in bracket x =  thita 0 + thita 1 x  i.e (see ss 39.21 live 1) -- h0(x) = 0o+01x
# Suppose i have a problem statement with  x and y with datapoints -- then I am going to create best-fit line -- best fit
# line is basically given by above mention equation -- here what does thita 0 means -- thita 0 over here is something
# called as Intercept -- Intercept basically means that when your x is 0 then h thita of x = thita 0 -- so when your x = 0
# that basically means h thita of x is nothing but thita 0. So in this particular case intercept basically indicate at what
# point you are meeting the y axis so this this particular point is your intercept -- when your x = 0 at that point of time
# you will be seeing that this line is intercepting the y axis -- whatever value this will be i.e your intercept.
# What is thita 1 -- this is nothing but slope or coefficeint -- what does basically it indicate -- (see SS 40.56 live 1)
# suppose on x axis I have two points 4 and 5 and base on this I can find two points on the best-fit line similarly on y axs
# if I try to map those two units so what does basically slope says -- with the unit movement -- one unit movement towards
# the x axis what is the unit movement towards the y axis matlab x axis pe 4 se 5 par janepe jitna movement hota hai utnahi
# y axis pe kitna hota hai -- so this is called slope or coefficient.
# so thita 0 is Intercept while thita one is coefficient while xi is nothing but the datapoints
# What is the aim of LR -- In LR I need to findout the best-fit line in a such way that the distance between this datapoint
# I have on bar and the predicted points should be very very less. Suppose I am creating a best-fit linev -- so wrt distance
# between my predicted datapoints and actual datapoints should be minimal -- then only I will be able to say that this is 
# the best-fit line (see SS 42.37 live 1). When I can say this is the exactally best-fit line -- when I tried to calculate 
# distance between actual datapoints and my predicted datapoints It should be minimal -- that distance should be minimal --
# if I do the summation of the all the distance it should be minimal i.e the main point over here so for that what I can do 
# -- suppose these are my datapints then why not play and create multiple lines on graph and compare -- we can create 
# multiple lines and whoever is giving less points like this I will go and select that -- but how many iterations I will do 
# -- how you will come to know that this line is the best line -- so for that specific purpose we should start at one point
# and we should lead towards finding the best-fit line -- start at one point and we should lead towards finding the best-fit
# line -- so for this particular purpose we create something called as a cost function.
# my hypothesis is h0(x) = 0o + 01x
# Now cost function -- which is supersuper imp -- what is cost function -- when I am finding distance between actual datapnt
# and the predicted datapoints the summation of distance should be minimal -- so if I want to find out this distance then 
# I will be using one more equation -- cost function -- h thita of x - y it means predicted point will be given by h thita 
# of x and then I am going to square it bcz I may get the negative values so I need to square it -- I need to do summation
# also -- i = 1 to complete m -- lets suppose I am taking the number of datapoint here as complete m bcz I need to calculate
# distance between all the datapoints wrt predicted and actual points so after this I need to divide by 1 by 2m -- reason
# why we are dividing by 1 by m -- 1 by m will give us the average of all the values that we have -- the specific reason
# why we are dividing 1 by 2 is for the  derivation purpose -- it help us to make our equation very much simpler so that 
# later on when I am updating the weights -- when I am saying weights I am saying thita 0 and thita 1 at that point of time
# -- you will be able to see that particular value when we probably do the derivative -- it will help uss to do it.
# In order to find out best-fit line I need to keep changing thita 0 and thita 1 unless and until I get the best-fit line.
# If I keep on updating thita 0 and thita 1 I probably need cost function -- cost function my main aim is to find minimal
# summation. In cost function I am going to dividing 1 by 2 m this will give me average cost function -- it will help us in
# derivation -- (see SS 49.16 live 1) this entire equation is called as Squared Error Function.
# What we need to solve -- I need to minimize (see ss live 51.12 live 1) this particular value i.e 1 by 2m summation of i=1
# to m and then this will basically be h thita of x of i - y of i whole square -- we need to minimize this by adjusting 
# parameter thita 0 and thita 2 -- this entire is nothing but j of thita 0 , thita 1 and we need to minimize this so this is
# our task -- this is called as squared error function.
# Now lets try to compare with two different things -- one is the hypothesis testing and one is wrt the cost function -- let
# take an example -- right now my equation of the hypothesis is nothing but h thita of x = thita 0 + thita 1 * x
# h0(x) = 0o+01x -- If thita 0 is 0 ( 0o = 0) -- it indicate that -- the base-fit line passes through the origin as thita0 
# is nothing but intercept -- and this is nothing but h thita of x = thita 1 * x (h0(x) =  01x) -- so my equation will be 
# like the above -- so for right now consider your thita 0 = 0 it is passing through the origin so the above equation im gtg
# Lets take one example and let us try to solve it -- if I have h thita of x -- so this is my new hypothesis considering 
# that my intercept is passing through the origin (h0(x)=01x) -- so wrt this lets say that on x axis I have 1,2,3 and on
# y axis I have 1,2,3 now lets consider that if I have 3 datapoints like (1,1)(2,2)(3,3) so map this datapoints on bar as x
# and y (see SS 53.58 live 1) so this are the my datapoints from the dataset I have -- 
# First Scnenario -- now if I consider thita 1 as 1 then
# the straight line will pass through the all the points which we have mapped on the bar this same points become our predctn
# point also -- it passes through all points when thita 1 = 1 thita 1 is nothing but slope so when slope = 1 in this scenaro
# the it passes through all the points -- now go ahead and calculate your j of thita (see SS 55.36 live 1) -- formula of 
# j of thita is 1 by 2m summation of i = 1 to 3 (bcz 3 points are there) h thita of xi - yi whole square -- now lets go 
# ahead and compute -- in this scenario what will happen -- 1 by 2m then h thita of x is 1 and y of i is also 1 so this will
# become 1-1 whole square + next point is also falling into 2,2 so this will become 2-2 whole square , next point is  3-3 
# 3 square so this total will become 0. -- So when thita 1 is 1 then j of thita 1 is 0 so j of thita 1 is a cost function
# Now draw the cost function map -- lets say x axis have thita with points [0.5,1,1.5,2,2.5] similarly I have on y axis I 
# have j of thita 1 with same points -- so right now my thita 1 is 1 at this particular point what did I get J of thita 1 
# is nothing but 0 -- so this will be my first point.
# In the Second scenario my thita 1 is 0.5 -- so when my thita 1 is 0.5 that tell me what are the points that I will get 
# for x = 1 (h0(x) = 01x i.e 0.5*1 = 0.5) so y will come at 0.5 (see SS 57.53 live 1) then similarly when x = 2 (0.2*2 = 1)
# so for x = 2 y point will come at 1 and then similarly for x = 3 y point will come at 1.5 -- so in this case when I create
# my best-fit line by joining this points -- here definately slope is decresing so ig I go and calculate J of thita when 
# thita 0f 1 is 0.5 J of Thita 1 = 1 by 2m summation of i = 1 to 3 h thita of x of i - y of i whole square  -- xi is the 
# (real point) actual point while y i is the predicted point on the best-fit line.
# 1/2m [(0.5-1)sq+(1-2)sq+(1.5-3)sq] == so final answer is 0.58 so when thita 1 is 0.5 we are getting J thita of 1 as 0.58
# plot this J thita of 1 values of both the scenarios when thita of 1 is 1 and thita of 1 is 0.5 (see SS 1:01 live 1).
# In third scenario thita 1 is 0 at this the value J thita 1 will be 1/6[1sq+4sq+9sq] = 2.3 so on the graph plot 2.3 on the
# graph of gradient descent.
# Now when my thita 1 = 2 then for x = 1 (h0(x))=01x i.e 2*1=2 now calculate J thita of x = 1/2m summation of 1=1 to m 
# (h thita of xi - yof i )sq = 1/6((2-1)+(4-2)+(6-3))sq = 
# so considering all the values of thita 1 I will get the values at different location on the gradient descent bar so when I
# join together those points I will be getting one kind of curve there and that curve is called as GRADIENT DESCENT.
# (see SS 1:04 live 1) so this GD will play very very imp role in making sure that you get the right thita 1 value or right 
# slope value -- which is the most suitable point i.e point which touch x-axis -- that point is called as GLOBAL MINIMA --
# bcz out of all the lines which is the best-fit line -- that was the best fit line when my thita 1 is 0, J of Thita is 0
# so that is the best fit line -- so when I have best-fit line my point come at global minima -- at the global minima the 
# distance between the predicted and the actual points is the less -- so this specific point is called as global minima.

# %%
# Here we are assuming thita 1 as 0,0.5,1,2 means we are here assuming things and then calculating the GD -- but thing 
# should be that probabally you should come to one point over top of the line which curve right half of GD and then from 
# there you reach towards global minima so for that purpose how to do that -- means how do I first of all come to the point 
# & then towards the global minima -- so for that specific case we will be using convergence specific algorithm bzz if I 
# come to one specific point after that I just need to keep on updating thita 1 instead of using diff diff thita 1 values
# so for this we use something called as convergence algorithm.
# The Convergence algorithm basically says repeat untill convergence -- that means I am in a while loop -- and here I am 
# basically going to update my thita value which will be given by this notation {0j:=0j-alpha @/@0j J(0o,01)} (see SS 1:06)
# means after we reach to a specific point of thita after performing this particular operation we should be able to come to
# the global minima and @/@0j J(0o,01) this is know as something derivative. -- derivative basically means I am trying to 
# find the slope. This equation will woek definately. Suppose I want to come from upper point to the global minima so by  
# what speed I should be coming -- If my learning rate value is bigger then by what speed I will be coming -- bcz usually 
# we select learning rate as 0.01 if I select small number then it will take small small steps to come towards the GM. -- 
# but if I take alpha (learning rate) value as a huge value then the value of thita 1 keep jumping over here and there on 
# the curve and would never reach the GM so it will be good decision to take the value of alpha as 0.01.
# What if my cost function has a local minima (see diagram 1) suppose one of my point iis coming over up and then finally 
# to local minima then what will happen in this case -- So if we stuck in the local minima but usually wrt gradient descent 
# and the derivative equation we are using we do not get stuck in the local minima bcz our GD in this particular scenario
# will always look like full curve. The cost function we use will not give us the local minima.

# %%
# GRADIENT DESCENT ALGORITHM
7421201-
